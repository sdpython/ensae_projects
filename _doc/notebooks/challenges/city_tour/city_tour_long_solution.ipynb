# %% [markdown]
# # Longer city tours (solution)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %%
from jyquickhelper import add_notebook_menu
add_notebook_menu()
# Out:
# <div id="my_id_menu_nb">run previous cell, wait for 2 seconds</div>
# <script>
# function repeat_indent_string(n){
#     var a = "" ;
#     for ( ; n > 0 ; --n) {
#         a += "    ";
#     }
#     return a;
# }
# var update_menu_string = function(begin, lfirst, llast, sformat, send, keep_item) {
#     var anchors = document.getElementsByClassName("section");
#     if (anchors.length == 0) {
#         anchors = document.getElementsByClassName("text_cell_render rendered_html");
#     }
#     var i,t;
#     var text_menu = begin;
#     var text_memo = "<pre>\nlength:" + anchors.length + "\n";
#     var ind = "";
#     var memo_level = 1;
#     var href;
#     var tags = [];
#     var main_item = 0;
#     for (i = 0; i <= llast; i++) {
#         tags.push("h" + i);
#     }
#
#     for (i = 0; i < anchors.length; i++) {
#         text_memo += "**" + anchors[i].id + "--\n";
#
#         var child = null;
#         for(t = 0; t < tags.length; t++) {
#             var r = anchors[i].getElementsByTagName(tags[t]);
#             if (r.length > 0) {
# child = r[0];
# break;
#             }
#         }
#         if (child == null){
#             text_memo += "null\n";
#             continue;
#         }
#         if (anchors[i].hasAttribute("id")) {
#             // when converted in RST
#             href = anchors[i].id;
#             text_memo += "#1-" + href;
#             // passer à child suivant (le chercher)
#         }
#         else if (child.hasAttribute("id")) {
#             // in a notebook
#             href = child.id;
#             text_memo += "#2-" + href;
#         }
#         else {
#             text_memo += "#3-" + "*" + "\n";
#             continue;
#         }
#         var title = child.textContent;
#         var level = parseInt(child.tagName.substring(1,2));
#
#         text_memo += "--" + level + "?" + lfirst + "--" + title + "\n";
#
#         if ((level < lfirst) || (level > llast)) {
#             continue ;
#         }
#         if (title.endsWith('¶')) {
#             title = title.substring(0,title.length-1).replace("<", "&lt;").replace(">", "&gt;").replace("&", "&amp;")
#         }
#
#         if (title.length == 0) {
#             continue;
#         }
#
#         while (level < memo_level) {
#             text_menu += "</ul>\n";
#             memo_level -= 1;
#         }
#         if (level == lfirst) {
#             main_item += 1;
#         }
#         if (keep_item != -1 && main_item != keep_item + 1) {
#             // alert(main_item + " - " + level + " - " + keep_item);
#             continue;
#         }
#         while (level > memo_level) {
#             text_menu += "<ul>\n";
#             memo_level += 1;
#         }
#         text_menu += repeat_indent_string(level-2) + sformat.replace("__HREF__", href).replace("__TITLE__", title);
#     }
#     while (1 < memo_level) {
#         text_menu += "</ul>\n";
#         memo_level -= 1;
#     }
#     text_menu += send;
#     //text_menu += "\n" + text_memo;
#     return text_menu;
# };
# var update_menu = function() {
#     var sbegin = "";
#     var sformat = '<li><a href="#__HREF__">__TITLE__</a></li>';
#     var send = "";
#     var keep_item = -1;
#     var text_menu = update_menu_string(sbegin, 2, 4, sformat, send, keep_item);
#     var menu = document.getElementById("my_id_menu_nb");
#     menu.innerHTML=text_menu;
# };
# window.setTimeout(update_menu,2000);
#             </script>

# %% [markdown]
# ## Level 1

# %%
from ensae_projects.data.data_geo_streets import get_seattle_streets, shapely_records
from ensae_projects.data.data_geo_streets import seattle_streets_set_small, folium_html_street_map

name = get_seattle_streets()
shapes, records, fields = shapely_records(name)
edges_index, edges, vertices, distances = seattle_streets_set_small(shapes, records)
folium_html_street_map(edges_index, shapes, html_width="50%", zoom_start=15)
# Out:
# <pyensae.notebook_helper.folium_helper.folium_html_map.<locals>.CustomFoliumMap at 0x1f7b7b67fd0>

# %%
from ensae_projects.data.data_geo_streets import plot_streets_network
plot_streets_network(edges_index, edges, vertices, shapes, figsize=(10,10))

# %%
from ensae_projects.challenge.city_tour import best_euler_path
couples, solution, distance = best_euler_path(edges_index=edges_index, edges=edges,
                                              distances=distances, vertices=vertices, fLOG=print)
"distance", distance
# Out:
# [best_euler_path] distance_vertices #edges=24
# [best_euler_path] bellman_distances
# [bellman_distances] iteration=1 modif=74 #dist=122 sum_values=0.2693181551365076 avg=0.002207525861774652
# [bellman_distances] iteration=2 modif=96 #dist=206 sum_values=0.6190441810958587 avg=0.0030050688402711587
# [bellman_distances] iteration=3 modif=140 #dist=302 sum_values=1.31317150187087 avg=0.004348250006194934
# [bellman_distances] iteration=4 modif=100 #dist=306 sum_values=1.276032944608329 avg=0.004170042302641598
# [bellman_distances] iteration=5 modif=58 #dist=306 sum_values=1.2080772783633562 avg=0.003947964961971752
# [bellman_distances] iteration=6 modif=26 #dist=306 sum_values=1.1881614211882434 avg=0.003882880461399488
# [bellman_distances] iteration=7 modif=14 #dist=306 sum_values=1.1840644116345607 avg=0.003869491541289414
# [bellman_distances] iteration=8 modif=6 #dist=306 sum_values=1.1840644116345607 avg=0.003869491541289414
# [bellman_distances] iteration=9 modif=0 #dist=306 sum_values=1.1840644116345607 avg=0.003869491541289414
# [best_euler_path] degrees and distances between odd vertices
# [best_euler_path] matching #odd=6, #odd_dist=30
# [best_euler_path] build solution
# [best_euler_path] order edges to get the path #edges=31
# [best_euler_path] done.
# ('distance', 0.04360778144581235)

# %%
from ensae_projects.challenge.city_tour import euler_path
plot_streets_network(edges_index, edges, vertices, shapes, order=solution, figsize=(10,10))

# %% [markdown]
# ## Level 2

# %%
from ensae_projects.data.data_geo_streets import seattle_streets_set_level2
edges_index, edges, vertices, distances = seattle_streets_set_level2(shapes, records)
folium_html_street_map(edges_index, shapes, html_width="80%", zoom_start=14)
# Out:
# <pyensae.notebook_helper.folium_helper.folium_html_map.<locals>.CustomFoliumMap at 0x1f7bab5b8d0>

# %%
from ensae_projects.challenge.city_tour import best_euler_path
couples, solution, distance = best_euler_path(edges_index=edges_index, edges=edges,
                                              distances=distances, vertices=vertices, fLOG=print)
"distance", distance
# Out:
# [best_euler_path] distance_vertices #edges=129
# [best_euler_path] bellman_distances
# [bellman_distances] iteration=1 modif=472 #dist=730 sum_values=1.343021617643861 avg=0.0018397556406080286
# [bellman_distances] iteration=2 modif=860 #dist=1518 sum_values=4.245944254876766 avg=0.0027970647265327837
# [bellman_distances] iteration=3 modif=2372 #dist=3516 sum_values=17.753596984838655 avg=0.005049373431410311
# [bellman_distances] iteration=4 modif=5056 #dist=6930 sum_values=59.55248525662767 avg=0.008593432215963589
# [bellman_distances] iteration=5 modif=4586 #dist=7140 sum_values=59.644533938905646 avg=0.008353576181919559
# [bellman_distances] iteration=6 modif=3946 #dist=7140 sum_values=57.21216159740017 avg=0.008012907786750723
# [bellman_distances] iteration=7 modif=3224 #dist=7140 sum_values=55.524763289871565 avg=0.007776577491578651
# [bellman_distances] iteration=8 modif=2544 #dist=7140 sum_values=53.993858198750395 avg=0.007562165013830588
# [bellman_distances] iteration=9 modif=1948 #dist=7140 sum_values=52.94827051155641 avg=0.0074157241612824104
# [bellman_distances] iteration=10 modif=1486 #dist=7140 sum_values=52.29904567140725 avg=0.007324796312522024
# [bellman_distances] iteration=11 modif=1092 #dist=7140 sum_values=51.84175689729086 avg=0.0072607502657270106
# [bellman_distances] iteration=12 modif=766 #dist=7140 sum_values=51.46232477978224 avg=0.0072076085125745435
# [bellman_distances] iteration=13 modif=504 #dist=7140 sum_values=51.21463543963939 avg=0.007172918128801034
# [bellman_distances] iteration=14 modif=336 #dist=7140 sum_values=51.044625992233314 avg=0.007149107281825394
# [bellman_distances] iteration=15 modif=178 #dist=7140 sum_values=50.9764419637885 avg=0.007139557698009594
# [bellman_distances] iteration=16 modif=108 #dist=7140 sum_values=50.944312220761496 avg=0.00713505773400021
# [bellman_distances] iteration=17 modif=50 #dist=7140 sum_values=50.935951448788025 avg=0.007133886757533337
# [bellman_distances] iteration=18 modif=30 #dist=7140 sum_values=50.9358436916943 avg=0.007133871665503403
# [bellman_distances] iteration=19 modif=12 #dist=7140 sum_values=50.9358436916943 avg=0.007133871665503403
# [bellman_distances] iteration=20 modif=0 #dist=7140 sum_values=50.9358436916943 avg=0.007133871665503403
# [best_euler_path] degrees and distances between odd vertices
# [best_euler_path] matching #odd=34, #odd_dist=1122
# [best_euler_path] build solution
# [best_euler_path] order edges to get the path #edges=161
# [best_euler_path] done.
# ('distance', 0.17361084069482008)

# %%
from ensae_projects.challenge.city_tour import euler_path
plot_streets_network(edges_index, edges, vertices, shapes, order=solution, figsize=(20,20))

# %% [markdown]
# ## Level 3

# %%
from ensae_projects.data.data_geo_streets import seattle_streets_set_level3
edges_index, edges, vertices, distances = seattle_streets_set_level3(shapes, records)
# We skip display as it takes some time
# folium_html_street_map(edges_index, shapes, html_width="80%", zoom_start=14)

# %%
from ensae_projects.challenge.city_tour import best_euler_path
if False:
    # Be prepared, it is quite long, the bellman implementation has to be improved.
    couples, solution, distance = best_euler_path(edges_index=edges_index, edges=edges,
                                                  distances=distances, vertices=vertices, fLOG=print)
    "distance", distance
# Out:
# [best_euler_path] distance_vertices #edges=1171
# [best_euler_path] bellman_distances
# [bellman_distances] iteration=1 modif=4484 #dist=6814 sum_values=15.275850826136931 avg=0.0022418331121421974
# [bellman_distances] iteration=2 modif=9112 #dist=15344 sum_values=53.36451873389275 avg=0.003477875308517515
# [bellman_distances] iteration=3 modif=34068 #dist=45440 sum_values=306.00636143721806 avg=0.006734294925995116
# [bellman_distances] iteration=4 modif=148362 #dist=169028 sum_values=2411.6895687539195 avg=0.014267988550736679
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-d339d31fa0ea> in <module>()
#       1 from ensae_projects.challenge.city_tour import best_euler_path
#       2 couples, solution, distance = best_euler_path(edges_index=edges_index, edges=edges,
# ----> 3                                               distances=distances, vertices=vertices, fLOG=print)
#       4 "distance", distance
#
# C:\xadupre\__home_\GitHub\ensae_projects\src\ensae_projects\challenge\city_tour.py in best_euler_path(edges, vertices, distances, edges_index, algo, fLOG)
#     585     if fLOG:
#     586         fLOG("[best_euler_path] bellman_distances")
# --> 587     dist = bellman_distances(edges, distances, fLOG=fLOG)
#     588     if fLOG:
#     589         fLOG("[best_euler_path] degrees and distances between odd vertices")
#
# C:\xadupre\__home_\GitHub\ensae_projects\src\ensae_projects\challenge\city_tour.py in bellman_distances(edges, distances, fLOG)
#     367                 # no need to continue as no update during the last iteration
#     368                 continue
# --> 369             for (aa, bb), d2 in dist.items():
#     370                 # not the most efficient
#     371                 if b == aa and a != bb:
#
# KeyboardInterrupt:
