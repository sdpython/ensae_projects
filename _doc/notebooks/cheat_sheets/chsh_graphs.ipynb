# %% [markdown]
# # Cheat Sheet on Graphs
#
# Links, pointers on many plotting libraries.

# %%
from jyquickhelper import add_notebook_menu
add_notebook_menu()
# Out:
# <div id="my_id_menu_nb">run previous cell, wait for 2 seconds</div>
# <script>
# function repeat_indent_string(n){
#     var a = "" ;
#     for ( ; n > 0 ; --n)
#         a += "    ";
#     return a;
# }
# // look up into all sections and builds an automated menu //
# var update_menu_string = function(begin, lfirst, llast, sformat, send, keep_item, begin_format, end_format) {
#     var anchors = document.getElementsByClassName("section");
#     if (anchors.length == 0) {
#         anchors = document.getElementsByClassName("text_cell_render rendered_html");
#     }
#     var i,t;
#     var text_menu = begin;
#     var text_memo = "<pre>\nlength:" + anchors.length + "\n";
#     var ind = "";
#     var memo_level = 1;
#     var href;
#     var tags = [];
#     var main_item = 0;
#     var format_open = 0;
#     for (i = 0; i <= llast; i++)
#         tags.push("h" + i);
#
#     for (i = 0; i < anchors.length; i++) {
#         text_memo += "**" + anchors[i].id + "--\n";
#
# ...

# %% [markdown]
# ## Notebook start
#
# To include graphs in a notebook, many modules require to execute a line before it is imported.
#
# [matplotlib](http://matplotlib.org/)

# %%
# %matplotlib inline

# %% [markdown]
# Changing style

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# Available styles:

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %% [markdown]
# [bokeh](http://bokeh.pydata.org/en/latest/)

# %%
import bokeh.plotting as bplt
bplt.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="699839b9-3c7e-404f-acdd-65513a04a35a">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# [pyecharts](https://github.com/pyecharts/pyecharts)

# %%
import pyecharts

# %% [markdown]
# ## Change style
#
# Only with [matplotlib](http://matplotlib.org/)

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# ## If you want to draw a...

# %% [markdown]
# ### Basic graph as images
#
# * [maplotlib](http://matplotlib.org/)
# * [pandas.DataFrame.plot](http://pandas.pydata.org/pandas-docs/stable/visualization.html)

# %% [markdown]
# ### Basic graphs as javascript
#
# * [bokeh](http://bokeh.pydata.org/en/latest/)
# * [pygal](http://www.pygal.org/en/latest/)
# * [C3.js](http://www.xavierdupre.fr/app/jyquickhelper/helpsphinx/notebooks/notebook_graph_js.html)
# * [pyecharts](https://github.com/pyecharts/pyecharts)

# %% [markdown]
# ### Animated graphs
#
# * [bokeh](http://bokeh.pydata.org/en/latest/)

# %% [markdown]
# ### Maps
#
# * [cartopy](http://scitools.org.uk/cartopy/)
# * [folium](https://github.com/python-visualization/folium)

# %% [markdown]
# ### Statistical graphs
#
# * [seaborn](http://stanford.edu/~mwaskom/software/seaborn/)

# %% [markdown]
# ### Networks
#
# * [networkx](https://networkx.github.io/)
# * [graphviz](https://pypi.python.org/pypi/graphviz)

# %% [markdown]
# ### More
#
# * [10 plotting librairies](http://www.xavierdupre.fr/app/jupytalk/helpsphinx/notebooks/10_plotting_libraries.html#plottinglibrariesrst)

# %% [markdown]
# ## Notebooks and Python
#
# * [Graphes - énoncé](http://www.xavierdupre.fr/app/actuariat_python/helpsphinx/notebooks/seance6_graphes_enonce.html) (French)
# * [Rappel de ce que vous savez déjà mais avez peut-être oublié](http://www.xavierdupre.fr/app/ensae_teaching_cs/helpsphinx/notebooks/td2_eco_rappels_1a.html)
